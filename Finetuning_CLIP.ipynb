# %%
### 1. Installing packages and Dependencies
import os
print(os.getcwd())
# Out:
# /content

# %%
# !git clone https://github.com/lakshminarayanan678/Finetuning_CLIP.git
# Out:
# Cloning into 'Finetuning_CLIP'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 9 (delta 0), reused 6 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (9/9), done.

# %%
# %cd /content/Finetuning_CLIP/
# !mkdir HI
# Out:
# /content/Finetuning_CLIP

# %%
# !git config --global user.email "lakshminarayanan.m678@gmail.com"
# !git config --global user.name "Lakshminarayanan M"

# !git config --global credential.helper store

# %%
# %%writefile ~/.git-credentials
# https://lakshminarayanan678:{pat}
# Out:
# Writing /root/.git-credentials

# %%
# !git remote -v
# !git remote set-url origin https://lakshminarayanan678:{pat}@github.com/lakshminarayanan678/Finetuning_CLIP.git
# !git remote -v
# Out:
# origin	https://github.com/lakshminarayanan678/Finetuning_CLIP.git (fetch)
# origin	https://github.com/lakshminarayanan678/Finetuning_CLIP.git (push)
# origin	https://lakshminarayanan678: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@github.com/lakshminarayanan678/Finetuning_CLIP.git (fetch)
# origin	https://lakshminarayanan678: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@github.com/lakshminarayanan678/Finetuning_CLIP.git (push)

# %%
# !git add .
# !git commit -m "Pushing an demo file to learn git push from Colab"
# !git push origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Everything up-to-date

# %%
with open('README.md', 'r') as f:
    text = f.read()

print(text)

new_text = """
### Finetuning_CLIP
Heyyy
"""

with open('README.md', 'w') as f:
    f.write(new_text)
# Out:
# ### Finetuning_CLIP
# Heyyy

# %%
# !git add .
# !git commit -m "Pushing an demo file to learn git push from Colab"
# !git push -u origin main
# Out:
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# Branch 'main' set up to track remote branch 'main' from 'origin'.
# Everything up-to-date
